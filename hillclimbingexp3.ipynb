# %%
#objective function
def objective_function(x):
    return -((x-8)**2)+64
print(objective_function(9))
# Out:
# 63

# %%
#objective function
def objective_function(x):
    return -((x-10)**2)+100
print(objective_function(6))
# Out:
# 84

# %%
from typing import Sized
#objective function
def objective_function(x):
    return -(x**2)+10


#Hill Climbing function
def hill_climbing(start,step_size,max_iterations):
   current= start
   current_value=objective_function(current)
   for i in range(max_iterations):
      left=current- step_size
      right=current = step-Size
      left_value= objective_function(left)
      right_value=objective_function(right)

      if left_value >current_value:
       current=left
       current_value=left_value
      elif right_value >current_value:
        current=right
        current_value=right_value
      else:
        break
        return current, current_value


start = float(input("enter the string value:"))
step_size=float(input("enter the step size:"))
max_iteration=int(input("enter the maximum number of iteration:"))
best_position,best_value = hill_climbing(start,step-size,max_iteration)
print("\nthe best poisition=",best_position)
print("the best value=",best_value)
# Out:
# enter the string value:1
